# %% [markdown]
# # Checking installation setup
#
# You should run this notebook before the workshop.  Please contact the organizers if you have any issue / question (o.koch@criteo.com, f.vasile@criteo.com)

# %% [markdown]
# ### Check software versions

# %%
import numpy
import tensorflow as tf
import pandas as pd
import sys

print ("Python version: " + sys.version)
print("Tensorflow version: " + tf.__version__)
# Out:
# Python version: 3.5.2 (default, Nov 23 2017, 16:37:01)
# [GCC 5.4.0 20160609]
# Tensorflow version: 1.8.0

# %% [markdown]
# ### Read the movie lens dataset

# %%
rating_df = pd.read_csv('home/o.koch/ml100k/u.data', sep='\t', names=['user', 'item', 'rate', 'time'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f98f880dc585> in <module>()
# ----> 1 rating_df = pd.read_csv('home/o.koch/ml100k/u.data', sep='\t', names=['user', 'item', 'rate', 'time'])
#
# ...

# %%
rating_df
# Out:
#        user  item  rate       time
# 0       196   242     3  881250949
# 1       186   302     3  891717742
# 2        22   377     1  878887116
# 3       244    51     2  880606923
# 4       166   346     1  886397596
# 5       298   474     4  884182806
# 6       115   265     2  881171488
# 7       253   465     5  891628467
# 8       305   451     3  886324817
# 9         6    86     3  883603013
# 10       62   257     2  879372434
# 11      286  1014     5  879781125
# 12      200   222     5  876042340
# 13      210    40     3  891035994
# 14      224    29     3  888104457
# 15      303   785     3  879485318
# 16      122   387     5  879270459
# 17      194   274     2  879539794
# 18      291  1042     4  874834944
# 19      234  1184     2  892079237
# 20      119   392     4  886176814
# 21      167   486     4  892738452
# 22      299   144     4  877881320
# 23      291   118     2  874833878
# 24      308     1     4  887736532
# 25       95   546     2  879196566
# ...
